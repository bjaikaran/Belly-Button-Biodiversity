# %%
import matplotlib
from matplotlib import style
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
import random as rnd

# %%
engine = create_engine("sqlite:///belly_button_biodiversity.sqlite", echo=False)
Base = automap_base()
Base.prepare(engine, reflect=True)
# Binding the SQLITE engine to the current Session (locking file)
session = Session(bind=engine)

# %%
# Verify tables and structure from SQLite database
inspector = inspect(engine)
tbl_names = inspector.get_table_names()
i =0 
for table in tbl_names:
    print(table)
    i = i+1
print("___________________________\nTotal of %s tables" %i)
# Out:
# otu
# samples
# samples_metadata
# ___________________________
# Total of 3 tables

# %%
OTU = Base.classes.otu
SAMPLES = Base.classes.samples
META = Base.classes.samples_metadata

# %%
OTU_COLS = []
columns = inspector.get_columns("otu")
for col in columns:
    OTU_COLS.append(col["name"])

# %%
SAMPLE_COLS = []
columns = inspector.get_columns("samples")
for col in columns:
    SAMPLE_COLS.append(col["name"])

# %%
META_COLS = []
columns = inspector.get_columns("samples_metadata")
for col in columns:
    META_COLS.append(col["name"])

# %%
OTU_df = pd.read_sql("SELECT * FROM otu", con=engine, columns=[OTU_COLS], index_col="otu_id")
SAMPLES_df = pd.read_sql("SELECT * FROM samples", con=engine, columns=[SAMPLE_COLS], index_col="otu_id")
META_df = pd.read_sql("SELECT * FROM samples_metadata", con=engine, columns=[META_COLS], index_col="SAMPLEID")

# %%
sample_names = SAMPLES_df.columns
sample_list_names = []
for col in sample_names:
    sample_list_names.append(col)
sample_list_names = sample_list_names[1:]

# %%
otu_desc = []
for item in OTU_df["lowest_taxonomic_unit_found"]:
    otu_desc.append(item)

# %%
meta_data = META_df.to_dict("index")
sample_lookup = {}

# %%
for k,v in meta_data.items():
    sample_lookup.update({"BB_"+str(k):v})

# %%
otu_id_sort = OTU_df.sort_index(ascending=False)

# %%
sample_values = SAMPLES_df

# %%
sample_values["sum"] = sample_values.sum(axis=1)

# %%
sample_values.sort_values("sum", ascending=False, inplace=True)

# %%
sample_values
# Out:
#         BB_940  BB_941  BB_943  BB_944  BB_945  BB_946  BB_947  BB_948  \
# otu_id
# 1795        10      40       2      11     141       2     102       8
# 922          1      27       1     278     129       1      45     185
# 944         19     178       0       8     274       7     135       9
# 2419        13     162       0       0     110      36     412      55
# 1167       163      24       0       0      32     217      27      18
# 2859       126      21       0       0      40     195     200      47
# 2539         1      92       0       0      10      18      23       9
# 2722         8     194       0       2      35     114     236      64
# 482        113       8       0       0       9      28       3      50
# 728          1       3       0       2      10       5      19     225
# 2011        11       0       0       0      12     159      15      19
# 943          0       0       0      19      37       0       0      57
# 909          0       0       0       0       7     116       7       1
# 41          71       4       0       3      14     153      13      10
# 2389         0      37       0       0       6       1       9       0
# 3450        37      84       0       0       6      24      46      13
# 1870         0       5       0       1       0       0       0       0
# 2308         0      10       0       4       0       4       1       8
# 3643         0       0       0       0       0       0       0      20
# 1314         3      28       0       0      20     100      11      10
# 3476         0       0       0       0       0       0       0       1
# 2782        12       3       0       0      14     116       3      18
# 2651         0      10       0       3      26       4     115       1
# 3218         0       0       0       0       0       0       0       0
# 1929         0       2       0       3       4       0       0       1
# 2396        11       0       0       0       0      16       2      12
# 1189        51       0       0       0       5      26       0      20
# 2318        40       1       0       0       7      31       6       6
# 2964        10      13       0       0      15     109      24       0
# 854          1       2       0       0       0       4       0       1
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 1662         0       0       0       0       0       0       0       0
# 573          0       0       0       0       0       0       0       0
# 2674         0       0       0       0       0       0       0       0
# 584          0       0       0       0       0       0       0       0
# 3245         0       0       0       0       0       0       0       0
# 3242         0       0       0       0       0       0       0       0
# 605          0       0       0       0       0       0       0       0
# 3237         0       0       0       0       0       0       0       0
# 521          0       0       0       0       0       0       0       0
# 2939         0       0       0       0       0       0       0       0
# 1748         0       0       0       0       0       0       0       0
# 3310         0       0       0       0       0       0       0       0
# 1811         0       0       0       0       0       0       0       0
# 1808         0       0       0       0       0       0       0       0
# 1806         0       0       0       0       0       0       0       0
# 2605         0       0       0       0       0       0       0       0
# 1798         0       0       0       0       0       0       0       0
# 3334         0       0       0       0       0       0       0       0
# 1790         0       0       0       0       0       0       0       0
# 1778         0       0       0       0       0       0       0       0
# 1773         0       0       0       0       0       0       0       0
# 495          0       0       0       0       0       0       0       0
# 1771         0       0       0       0       0       0       0       0
# 3318         0       0       0       0       0       0       0       0
# 1769         0       0       0       0       0       0       0       0
# 1759         0       0       0       0       0       0       0       0
# 503          0       0       0       0       0       0       0       0
# 1751         0       0       0       0       0       0       0       0
# 1750         0       0       0       0       0       0       0       0
# 1743         0       0       0       0       0       0       0       0
#
#         BB_949  BB_950  ...    BB_1563  BB_1564  BB_1572  BB_1573  BB_1574  \
# otu_id                  ...
# 1795         3     427  ...          1      537       26        3       14
# 922          1     123  ...         50        0        0       92       13
# 944          4      14  ...          0       22       13        0       15
# 2419         8       5  ...          1        0        2        5       16
# 1167         0       0  ...          0        0       93        0       14
# 2859         0       4  ...          0        0       19        0       14
# 2539         0       0  ...          0        0        2        0       13
# 2722         0       0  ...          0        0        2        0        5
# 482          0       0  ...          0        0       67        0       29
# 728          0       0  ...          0        0       25        0        0
# 2011         0       0  ...          0        0        0        0        0
# 943          0       0  ...         11        0        0        1        1
# 909          0       0  ...          0        0       14        0       18
# 41           0       0  ...          0        0       12        0        0
# 2389         0       0  ...          0        0        0        0        3
# 3450         0       0  ...          0        0       33        0        0
# 1870         0       0  ...          0        0        0        0        1
# 2308         0       0  ...          0        0        0        0        0
# 3643         0       0  ...          0        0       64        0        1
# 1314         0       0  ...          0        0       61        0        5
# 3476         0       0  ...        679        1        0        1        0
# 2782         0       0  ...          0        0        2        0        2
# 2651         0       0  ...          1        0        7        2        4
# 3218         0       0  ...          0        0        0        0        0
# 1929         0      13  ...          1        6        0        1        0
# 2396         0       0  ...          0        0        0        0        0
# 1189         0       0  ...          0        0       17        0        2
# 2318         0       0  ...          0        0        0        0        2
# 2964         0       0  ...          0        0        2        0        9
# 854          0       0  ...          0        0       24        0        0
# ...        ...     ...  ...        ...      ...      ...      ...      ...
# 1662         0       0  ...          0        0        0        0        0
# 573          0       0  ...          0        0        0        0        0
# 2674         0       0  ...          0        0        0        0        0
# 584          0       0  ...          0        0        0        0        0
